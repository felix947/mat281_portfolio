# %% [markdown]
# # MAT281 - Laboratorio N°05

# %% [markdown]
# ## Problema 01
#
# <img src="http://nelsoncos.com/wp-content/uploads/2017/02/sales-icon.png" width="360" height="360" align="center"/>
#
#
# EL conjunto de datos se denomina `company_sales_data.csv`, el cual contiene información tal como: número del mes, unidades, precio, etc.
#
# Lo primero es cargar el conjunto de datos y ver las primeras filas que lo componen:

# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(10,8)})

# %%
# cargar datos
df = pd.read_csv(os.path.join("data","company_sales_data.csv"))
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %% [markdown]
# El objetivo es tratar de obtener la mayor información posible de este conjunto de datos. Para cumplir este objetivo debe resolver las siguientes problemáticas:
#
# **Observación.-** Puedes ocupar las librerías de Matplolib o Seaborn.

# %% [markdown]
# 1. Lea el "total_profit" de todos los meses, muéstrelo usando un gráfico lineal y un gráfico de dispersión.

# %%
pd.DataFrame(df['total_profit']).head()
# Out:
#    total_profit
# 0        211000
# 1        183300
# 2        224700
# 3        222700
# 4        209600

# %%
sns.lineplot(x=df['month_number'],
            y=df['total_profit'],
            data=df,
            color='red')
plt.show()

# %%
sns.scatterplot(df['month_number'],
            df['total_profit'],
            data=df,
            color='red')
plt.show()

# %% [markdown]
# 2. Lea todos los datos de ventas de productos y muéstrelos utilizando un gráfico multilínea.

# %%
df_productos=df[['facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer']]
df_productos.head()
# Out:
#    facecream  facewash  toothpaste  bathingsoap  shampoo  moisturizer
# 0       2500      1500        5200         9200     1200         1500
# 1       2630      1200        5100         6100     2100         1200
# 2       2140      1340        4550         9550     3550         1340
# 3       3400      1130        5870         8870     1870         1130
# 4       3600      1740        4560         7760     1560         1740

# %%
sns.lineplot(
    data=df_productos)
plt.show()

# %% [markdown]
# 3. Lea los datos de ventas de productos de "facecream" y "facewash" y muéstrelos usando el gráfico de barras.

# %%
df_ventas_facecream=pd.DataFrame(df[['month_number','facecream']])
df_ventas_facecream.head()
# Out:
#    month_number  facecream
# 0             1       2500
# 1             2       2630
# 2             3       2140
# 3             4       3400
# 4             5       3600

# %%
sns.barplot(x=df_ventas_facecream['month_number'],
           y=df_ventas_facecream['facecream'])
plt.show()

# %%
df_ventas_facewash=pd.DataFrame(df[['month_number','facewash']])
df_ventas_facewash.head()
# Out:
#    month_number  facewash
# 0             1      1500
# 1             2      1200
# 2             3      1340
# 3             4      1130
# 4             5      1740

# %%
sns.barplot(x=df_ventas_facewash['month_number'],
           y=df_ventas_facewash['facewash'],
           data=df_ventas_facewash)
plt.show()

# %% [markdown]
# 4. Lea todos los datos de ventas de productos y muéstrelos utilizando un gráfico box-plot.

# %%
sns.boxplot(data=df_productos)
plt.show()

# %% [markdown]
# 5. Calcule los datos de ventas totales del año pasado para cada producto y muéstrelos usando un gráfico circular

# %%
df_productos_ventas_totales=pd.DataFrame(df.sum().drop(['month_number','total_profit','total_units'],axis=0))
df_productos_ventas_totales.columns=['Total ventas']
df_productos_ventas_totales
# Out:
#              Total ventas
# facecream           34480
# facewash            18515
# toothpaste          69910
# bathingsoap        114010
# shampoo             25410
# moisturizer         18515

# %%
df_productos_ventas_totales.plot(kind='pie', subplots=True, figsize=(42, 8))
plt.show()
